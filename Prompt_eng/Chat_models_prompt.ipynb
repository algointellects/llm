# %%
# %pip install langchain langchain_openai --upgrade
# Out:
# Collecting langchain
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/10/17/1d00f5ee2577d9c10c238c318b1fe6f6142a989c77277b6163d9549e3f93/langchain-0.1.6-py3-none-any.whl.metadata
#   Downloading langchain-0.1.6-py3-none-any.whl.metadata (13 kB)
# Collecting langchain_openai
#   Obtaining dependency information for langchain_openai from https://files.pythonhosted.org/packages/a2/86/05012e5276dde3004cfb0cb383f56983d3adcb5bc8ce13ebf21ce3ea3d26/langchain_openai-0.0.5-py3-none-any.whl.metadata
#   Downloading langchain_openai-0.0.5-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (3.8.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Obtaining dependency information for dataclasses-json<0.7,>=0.5.7 from https://files.pythonhosted.org/packages/91/ca/7219b838086086972e662c19e908694bdc6744537fb41b70392501b8b5e4/dataclasses_json-0.6.4-py3-none-any.whl.metadata
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl.metadata (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Obtaining dependency information for jsonpatch<2.0,>=1.33 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-community<0.1,>=0.0.18 (from langchain)
#   Obtaining dependency information for langchain-community<0.1,>=0.0.18 from https://files.pythonhosted.org/packages/bf/b4/1b1b22ab0c57320c5476b735cfe1500e49ddc4425df9e4c2e569e4c4472e/langchain_community-0.0.19-py3-none-any.whl.metadata
#   Downloading langchain_community-0.0.19-py3-none-any.whl.metadata (7.9 kB)
# Collecting langchain-core<0.2,>=0.1.22 (from langchain)
#   Obtaining dependency information for langchain-core<0.2,>=0.1.22 from https://files.pythonhosted.org/packages/c8/69/f9cd4ef398973830afe697417070d712ef1fbb3b9a768b8599f555deb687/langchain_core-0.1.22-py3-none-any.whl.metadata
#   Downloading langchain_core-0.1.22-py3-none-any.whl.metadata (6.0 kB)
# Collecting langsmith<0.1,>=0.0.83 (from langchain)
#   Obtaining dependency information for langsmith<0.1,>=0.0.83 from https://files.pythonhosted.org/packages/71/41/02beb3f8e22c258e0643c8b1e2ccf0d47888edcaae6895580a38f708b9ee/langsmith-0.0.90-py3-none-any.whl.metadata
#   Downloading langsmith-0.0.90-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy<2,>=1 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (1.24.3)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (1.10.8)
# Requirement already satisfied: requests<3,>=2 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (8.2.2)
# Collecting openai<2.0.0,>=1.10.0 (from langchain_openai)
#   Obtaining dependency information for openai<2.0.0,>=1.10.0 from https://files.pythonhosted.org/packages/26/a1/75474477af2a1dae3a25f80b72bbaf20e8296191ece7fff2f67984206f33/openai-1.12.0-py3-none-any.whl.metadata
#   Downloading openai-1.12.0-py3-none-any.whl.metadata (18 kB)
# Collecting tiktoken<0.6.0,>=0.5.2 (from langchain_openai)
#   Obtaining dependency information for tiktoken<0.6.0,>=0.5.2 from https://files.pythonhosted.org/packages/f1/62/73629527ff413c8ce20189d29eb52a91d6d4571e3214ef6d5a2c00ca4081/tiktoken-0.5.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading tiktoken-0.5.2-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Obtaining dependency information for marshmallow<4.0.0,>=3.18.0 from https://files.pythonhosted.org/packages/57/e9/4368d49d3b462da16a3bac976487764a84dd85cef97232c7bd61f5bdedf3/marshmallow-3.20.2-py3-none-any.whl.metadata
#   Downloading marshmallow-3.20.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Obtaining dependency information for typing-inspect<1,>=0.4.0 from https://files.pythonhosted.org/packages/65/f3/107a22063bf27bdccf2024833d3445f4eea42b2e598abfbd46f6a63b6cb0/typing_inspect-0.9.0-py3-none-any.whl.metadata
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dasaj\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.1)
# Requirement already satisfied: anyio<5,>=3 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain-core<0.2,>=0.1.22->langchain) (3.5.0)
# Collecting langsmith<0.1,>=0.0.83 (from langchain)
#   Obtaining dependency information for langsmith<0.1,>=0.0.83 from https://files.pythonhosted.org/packages/94/99/762b50b229516dd133e09c16213736b88d50d75e262b976e20cc244280ed/langsmith-0.0.87-py3-none-any.whl.metadata
#   Downloading langsmith-0.0.87-py3-none-any.whl.metadata (10 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2,>=0.1.22->langchain)
#   Obtaining dependency information for packaging<24.0,>=23.2 from https://files.pythonhosted.org/packages/ec/1a/610693ac4ee14fcdf2d9bf3c493370e4f2ef7ae2e19217d7a237ff42367d/packaging-23.2-py3-none-any.whl.metadata
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.10.0->langchain_openai)
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.10.0->langchain_openai)
#   Obtaining dependency information for httpx<1,>=0.23.0 from https://files.pythonhosted.org/packages/39/9b/4937d841aee9c2c8102d9a4eeb800c7dad25386caabb4a1bf5010df81a57/httpx-0.26.0-py3-none-any.whl.metadata
#   Downloading httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: sniffio in c:\users\dasaj\anaconda3\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain_openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in c:\users\dasaj\anaconda3\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain_openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\dasaj\anaconda3\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain_openai) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dasaj\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dasaj\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dasaj\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\dasaj\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\dasaj\anaconda3\lib\site-packages (from tiktoken<0.6.0,>=0.5.2->langchain_openai) (2022.7.9)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain_openai)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/56/ba/78b0a99c4da0ff8b0f59defa2f13ca4668189b134bd9840b6202a93d9a0f/httpcore-1.0.2-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.2-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain_openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      --------------------------------- ---- 51.2/58.3 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 58.3/58.3 kB 774.5 kB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\dasaj\anaconda3\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.10.0->langchain_openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\dasaj\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Downloading langchain-0.1.6-py3-none-any.whl (811 kB)
#    ---------------------------------------- 0.0/811.8 kB ? eta -:--:--
#    --- ------------------------------------ 61.4/811.8 kB 3.2 MB/s eta 0:00:01
#    --------- ------------------------------ 194.6/811.8 kB 2.0 MB/s eta 0:00:01
#    -------------- ------------------------- 286.7/811.8 kB 2.0 MB/s eta 0:00:01
#    ------------------------- -------------- 512.0/811.8 kB 2.7 MB/s eta 0:00:01
#    --------------------------------- ------ 675.8/811.8 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 811.8/811.8 kB 3.0 MB/s eta 0:00:00
# Downloading langchain_openai-0.0.5-py3-none-any.whl (29 kB)
# Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_community-0.0.19-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB 8.3 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.6 MB 5.8 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.6 MB 5.8 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.6 MB 5.8 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.6 MB 5.8 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.6 MB 5.8 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 2.8 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 2.8 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 2.8 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 2.8 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.6 MB 1.7 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.6 MB 1.7 MB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.6 MB 1.8 MB/s eta 0:00:01
#    ------------------------------ --------- 1.2/1.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.2/1.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------- -------- 1.3/1.6 MB 1.7 MB/s eta 0:00:01
#    --------------------------------- ------ 1.4/1.6 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 1.5/1.6 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.6 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 1.6/1.6 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.7 MB/s eta 0:00:00
# Downloading langchain_core-0.1.22-py3-none-any.whl (239 kB)
#    ---------------------------------------- 0.0/239.4 kB ? eta -:--:--
#    ------ --------------------------------- 41.0/239.4 kB 2.0 MB/s eta 0:00:01
#    --------------- ------------------------ 92.2/239.4 kB 1.3 MB/s eta 0:00:01
#    ------------------------- -------------- 153.6/239.4 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 204.8/239.4 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 239.4/239.4 kB 1.0 MB/s eta 0:00:00
# Downloading langsmith-0.0.87-py3-none-any.whl (55 kB)
#    ---------------------------------------- 0.0/55.4 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/55.4 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 55.4/55.4 kB 959.9 kB/s eta 0:00:00
# Downloading openai-1.12.0-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.7 kB ? eta -:--:--
#    ------- -------------------------------- 41.0/226.7 kB 1.9 MB/s eta 0:00:01
#    ------------------- -------------------- 112.6/226.7 kB 1.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 163.8/226.7 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  225.3/226.7 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 226.7/226.7 kB 1.2 MB/s eta 0:00:00
# Downloading tiktoken-0.5.2-cp311-cp311-win_amd64.whl (786 kB)
#    ---------------------------------------- 0.0/786.4 kB ? eta -:--:--
#    -- ------------------------------------ 41.0/786.4 kB 991.0 kB/s eta 0:00:01
#    ----- ---------------------------------- 112.6/786.4 kB 1.1 MB/s eta 0:00:01
#    -------- ------------------------------- 163.8/786.4 kB 1.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 204.8/786.4 kB 1.1 MB/s eta 0:00:01
#    ------------ --------------------------- 245.8/786.4 kB 1.2 MB/s eta 0:00:01
#    --------------- ------------------------ 297.0/786.4 kB 1.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 348.2/786.4 kB 1.1 MB/s eta 0:00:01
#    -------------------- ------------------- 409.6/786.4 kB 1.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 460.8/786.4 kB 1.1 MB/s eta 0:00:01
#    --------------------------- ------------ 532.5/786.4 kB 1.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 573.4/786.4 kB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 624.6/786.4 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 675.8/786.4 kB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 737.3/786.4 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  778.2/786.4 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 786.4/786.4 kB 1.1 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.9 kB ? eta -:--:--
#    --------------------- ------------------ 41.0/75.9 kB 960.0 kB/s eta 0:00:01
#    ---------------------------------------- 75.9/75.9 kB 1.0 MB/s eta 0:00:00
# Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.9 kB ? eta -:--:--
#    --------------------- ------------------ 41.0/76.9 kB 960.0 kB/s eta 0:00:01
#    ---------------------------------------- 76.9/76.9 kB 855.2 kB/s eta 0:00:00
# Downloading marshmallow-3.20.2-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.4 kB ? eta -:--:--
#    ---------------------------------------- 49.4/49.4 kB 834.2 kB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ---------------------------------------- 0.0/53.0 kB ? eta -:--:--
#    ------------------------------ --------- 41.0/53.0 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 53.0/53.0 kB 910.0 kB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Installing collected packages: typing-inspect, packaging, jsonpatch, h11, distro, tiktoken, marshmallow, langsmith, httpcore, langchain-core, httpx, dataclasses-json, openai, langchain-community, langchain_openai, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.1
#     Uninstalling packaging-23.1:
#       Successfully uninstalled packaging-23.1
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.32
#     Uninstalling jsonpatch-1.32:
#       Successfully uninstalled jsonpatch-1.32
# Successfully installed dataclasses-json-0.6.4 distro-1.9.0 h11-0.14.0 httpcore-1.0.2 httpx-0.26.0 jsonpatch-1.33 langchain-0.1.6 langchain-community-0.0.19 langchain-core-0.1.22 langchain_openai-0.0.5 langsmith-0.0.87 marshmallow-3.20.2 openai-1.12.0 packaging-23.2 tiktoken-0.5.2 typing-inspect-0.9.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.

# %%
import os
os.environ['OPENAI_API_KEY'] = 'Enter API Key'

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
)

chat = ChatOpenAI()

# %%
template = "What would be a good company name for a {company_description}. List 3 company names that you like. Make sure that the list is a numbered list."

system_message_prompt = SystemMessagePromptTemplate.from_template(template)
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt])

# %%
# Get a chat completion from the formatted messages
result = chat.invoke(
    chat_prompt.format_prompt(company_description="Data engineering").to_messages()
)

# %%
print(result.content)
# Out:
# 1. DataTech Solutions
# 2. DataWorks Engineering
# 3. Insightful Data Systems
