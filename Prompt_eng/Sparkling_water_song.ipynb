# %%
# %pip install langchain langchain_openai --upgrade
# Out:
# Requirement already satisfied: langchain in c:\users\dasaj\anaconda3\lib\site-packages (0.1.7)
# Collecting langchain
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/45/05/2d5c38c7fa1a091a61e018070b6878410d256be577e5154843d339e59b2c/langchain-0.1.9-py3-none-any.whl.metadata
#   Downloading langchain-0.1.9-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: langchain_openai in c:\users\dasaj\anaconda3\lib\site-packages (0.0.6)
# Collecting langchain_openai
#   Obtaining dependency information for langchain_openai from https://files.pythonhosted.org/packages/b9/66/e96a5b70b453c4f53830abee34208a18bdb8ad0c1765cbfbf80938d8b975/langchain_openai-0.0.7-py3-none-any.whl.metadata
#   Downloading langchain_openai-0.0.7-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (3.8.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (1.33)
# Collecting langchain-community<0.1,>=0.0.21 (from langchain)
#   Obtaining dependency information for langchain-community<0.1,>=0.0.21 from https://files.pythonhosted.org/packages/ae/98/3066c36e74f916ccb875afa40d9a4cee28755335ce7b6c675c25d4572920/langchain_community-0.0.22-py3-none-any.whl.metadata
#   Downloading langchain_community-0.0.22-py3-none-any.whl.metadata (8.1 kB)
# Collecting langchain-core<0.2,>=0.1.26 (from langchain)
#   Obtaining dependency information for langchain-core<0.2,>=0.1.26 from https://files.pythonhosted.org/packages/27/a0/6cd072db5ff0dec6b080575c0d976fc1bf22063d131f038496c650db7b84/langchain_core-0.1.26-py3-none-any.whl.metadata
#   Downloading langchain_core-0.1.26-py3-none-any.whl.metadata (6.0 kB)
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain)
#   Obtaining dependency information for langsmith<0.2.0,>=0.1.0 from https://files.pythonhosted.org/packages/91/ff/a330448e7f335298bed0129a71742ec8a96c41196a3d96304ed890ff25a7/langsmith-0.1.5-py3-none-any.whl.metadata
#   Downloading langsmith-0.1.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (1.24.3)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (1.10.8)
# Requirement already satisfied: requests<3,>=2 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain_openai) (1.12.0)
# Requirement already satisfied: tiktoken<1,>=0.5.2 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain_openai) (0.6.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\dasaj\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\dasaj\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\dasaj\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dasaj\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.1)
# Requirement already satisfied: anyio<5,>=3 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain-core<0.2,>=0.1.26->langchain) (3.5.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\dasaj\anaconda3\lib\site-packages (from langchain-core<0.2,>=0.1.26->langchain) (23.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\dasaj\anaconda3\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dasaj\anaconda3\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain_openai) (0.26.0)
# Requirement already satisfied: sniffio in c:\users\dasaj\anaconda3\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain_openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in c:\users\dasaj\anaconda3\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain_openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\dasaj\anaconda3\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain_openai) (4.9.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dasaj\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dasaj\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dasaj\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\dasaj\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\dasaj\anaconda3\lib\site-packages (from tiktoken<1,>=0.5.2->langchain_openai) (2022.7.9)
# Requirement already satisfied: httpcore==1.* in c:\users\dasaj\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain_openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dasaj\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain_openai) (0.14.0)
# Requirement already satisfied: colorama in c:\users\dasaj\anaconda3\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.10.0->langchain_openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\dasaj\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Downloading langchain-0.1.9-py3-none-any.whl (816 kB)
#    ---------------------------------------- 0.0/817.0 kB ? eta -:--:--
#    --- ------------------------------------ 61.4/817.0 kB 1.1 MB/s eta 0:00:01
#    --------- ------------------------------ 194.6/817.0 kB 2.0 MB/s eta 0:00:01
#    ------------------ --------------------- 368.6/817.0 kB 2.6 MB/s eta 0:00:01
#    -------------------------- ------------- 542.7/817.0 kB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 768.0/817.0 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 817.0/817.0 kB 3.0 MB/s eta 0:00:00
# Downloading langchain_openai-0.0.7-py3-none-any.whl (33 kB)
# Downloading langchain_community-0.0.22-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.7 MB 4.2 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.7 MB 4.0 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.7 MB 3.7 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.7 MB 2.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.7 MB 2.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.7 MB 2.9 MB/s eta 0:00:01
#    -------------- ------------------------- 0.6/1.7 MB 1.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.7 MB 2.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.7 MB 2.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.7 MB 2.0 MB/s eta 0:00:01
#    --------------------- ------------------ 0.9/1.7 MB 1.8 MB/s eta 0:00:01
#    --------------------- ------------------ 0.9/1.7 MB 1.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.0/1.7 MB 1.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.1/1.7 MB 1.6 MB/s eta 0:00:01
#    ------------------------ --------------- 1.1/1.7 MB 1.6 MB/s eta 0:00:01
#    ------------------------ --------------- 1.1/1.7 MB 1.6 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 1.6 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 1.6 MB/s eta 0:00:01
#    --------------------------------- ------ 1.4/1.7 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.5/1.7 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.5/1.7 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 1.6/1.7 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 1.5 MB/s eta 0:00:00
# Downloading langchain_core-0.1.26-py3-none-any.whl (246 kB)
#    ---------------------------------------- 0.0/246.4 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/246.4 kB 960.0 kB/s eta 0:00:01
#    -------------- ------------------------- 92.2/246.4 kB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 143.4/246.4 kB 1.1 MB/s eta 0:00:01
#    --------------------------------- ------ 204.8/246.4 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 246.4/246.4 kB 1.1 MB/s eta 0:00:00
# Downloading langsmith-0.1.5-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#    ---------------------------------------- 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: langsmith, langchain-core, langchain_openai, langchain-community, langchain
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.0.87
#     Uninstalling langsmith-0.0.87:
#       Successfully uninstalled langsmith-0.0.87
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.22
#     Uninstalling langchain-core-0.1.22:
#       Successfully uninstalled langchain-core-0.1.22
#   Attempting uninstall: langchain_openai
#     Found existing installation: langchain-openai 0.0.6
#     Uninstalling langchain-openai-0.0.6:
#       Successfully uninstalled langchain-openai-0.0.6
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.0.20
#     Uninstalling langchain-community-0.0.20:
#       Successfully uninstalled langchain-community-0.0.20
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.7
#     Uninstalling langchain-0.1.7:
#       Successfully uninstalled langchain-0.1.7
# Successfully installed langchain-0.1.9 langchain-community-0.0.22 langchain-core-0.1.26 langchain_openai-0.0.7 langsmith-0.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['OPENAI_API_KEY'] = 'enter key here'

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import (
    HumanMessage,
)

from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler


chat = ChatOpenAI(
    streaming=True, callbacks=[StreamingStdOutCallbackHandler()], temperature=0
)
resp = chat([HumanMessage(content="Write me a song about sparkling water.")])
# Out:
# C:\Users\dasaj\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[5], line 12
#       6 from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
#       9 chat = ChatOpenAI(
#      10     streaming=True, callbacks=[StreamingStdOutCallbackHandler()], temperature=0
#      11 )
# ---> 12 resp = chat([HumanMessage(content="Write me a song about sparkling water.")])
#
# File ~\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:691, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     683 @deprecated("0.1.7", alternative="invoke", removal="0.2.0")
#     684 def __call__(
#     685     self,
#    (...)
#     689     **kwargs: Any,
#     690 ) -> BaseMessage:
# --> 691     generation = self.generate(
#     692         [messages], stop=stop, callbacks=callbacks, **kwargs
#     693     ).generations[0][0]
#     694     if isinstance(generation, ChatGeneration):
#     695         return generation.message
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:408, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     406         if run_managers:
#     407             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 408         raise e
#     409 flattened_outputs = [
#     410     LLMResult(generations=[res.generations], llm_output=res.llm_output)
#     411     for res in results
#     412 ]
#     413 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     395 for i, m in enumerate(messages):
#     396     try:
#     397         results.append(
# --> 398             self._generate_with_cache(
#     399                 m,
#     400                 stop=stop,
#     401                 run_manager=run_managers[i] if run_managers else None,
#     402                 **kwargs,
#     403             )
#     404         )
#     405     except BaseException as e:
#     406         if run_managers:
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:577, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     573     raise ValueError(
#     574         "Asked to cache, but no cache found at `langchain.cache`."
#     575     )
#     576 if new_arg_supported:
# --> 577     return self._generate(
#     578         messages, stop=stop, run_manager=run_manager, **kwargs
#     579     )
#     580 else:
#     581     return self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain_openai\chat_models\base.py:456, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     452 if should_stream:
#     453     stream_iter = self._stream(
#     454         messages, stop=stop, run_manager=run_manager, **kwargs
#     455     )
# --> 456     return generate_from_stream(stream_iter)
#     457 message_dicts, params = self._create_message_dicts(messages, stop)
#     458 params = {
#     459     **params,
#     460     **({"stream": stream} if stream is not None else {}),
#     461     **kwargs,
#     462 }
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:65, in generate_from_stream(stream)
#      62 """Generate from a stream."""
#      64 generation: Optional[ChatGenerationChunk] = None
# ---> 65 for chunk in stream:
#      66     if generation is None:
#      67         generation = chunk
#
# File ~\anaconda3\Lib\site-packages\langchain_openai\chat_models\base.py:420, in ChatOpenAI._stream(self, messages, stop, run_manager, **kwargs)
#     417 params = {**params, **kwargs, "stream": True}
#     419 default_chunk_class = AIMessageChunk
# --> 420 for chunk in self.client.create(messages=message_dicts, **params):
#     421     if not isinstance(chunk, dict):
#     422         chunk = chunk.model_dump()
#
# File ~\anaconda3\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\openai\resources\chat\completions.py:663, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     611 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     612 def create(
#     613     self,
#    (...)
#     661     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     662 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 663     return self._post(
#     664         "/chat/completions",
#     665         body=maybe_transform(
#     666             {
#     667                 "messages": messages,
#     668                 "model": model,
#     669                 "frequency_penalty": frequency_penalty,
#     670                 "function_call": function_call,
#     671                 "functions": functions,
#     672                 "logit_bias": logit_bias,
#     673                 "logprobs": logprobs,
#     674                 "max_tokens": max_tokens,
#     675                 "n": n,
#     676                 "presence_penalty": presence_penalty,
#     677                 "response_format": response_format,
#     678                 "seed": seed,
#     679                 "stop": stop,
#     680                 "stream": stream,
#     681                 "temperature": temperature,
#     682                 "tool_choice": tool_choice,
#     683                 "tools": tools,
#     684                 "top_logprobs": top_logprobs,
#     685                 "top_p": top_p,
#     686                 "user": user,
#     687             },
#     688             completion_create_params.CompletionCreateParams,
#     689         ),
#     690         options=make_request_options(
#     691             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     692         ),
#     693         cast_to=ChatCompletion,
#     694         stream=stream or False,
#     695         stream_cls=Stream[ChatCompletionChunk],
#     696     )
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:1200, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1186 def post(
#    1187     self,
#    1188     path: str,
#    (...)
#    1195     stream_cls: type[_StreamT] | None = None,
#    1196 ) -> ResponseT | _StreamT:
#    1197     opts = FinalRequestOptions.construct(
#    1198         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1199     )
# -> 1200     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:889, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     880 def request(
#     881     self,
#     882     cast_to: Type[ResponseT],
#    (...)
#     887     stream_cls: type[_StreamT] | None = None,
#     888 ) -> ResponseT | _StreamT:
# --> 889     return self._request(
#     890         cast_to=cast_to,
#     891         options=options,
#     892         stream=stream,
#     893         stream_cls=stream_cls,
#     894         remaining_retries=remaining_retries,
#     895     )
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:980, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     977         err.response.read()
#     979     log.debug("Re-raising status error")
# --> 980     raise self._make_status_error_from_response(err.response) from None
#     982 return self._process_response(
#     983     cast_to=cast_to,
#     984     options=options,
#    (...)
#     987     stream_cls=stream_cls,
#     988 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-flpPj***************************************DhqB. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
